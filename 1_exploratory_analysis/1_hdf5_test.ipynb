# %%
import sys
sys.path.append('../')

# %%
from scripts.utils import data_path, set_mpl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import h5py

# %matplotlib inline

set_mpl()
# Out:
# matplotlib settings set

# %%
file = h5py.File(data_path+'/Schlemminger2022/2018_data_15min.hdf5', 'r')
print(file.keys())
# Out:
# <KeysViewHDF5 ['MISC', 'NO_PV', 'WITH_PV']>

# %%
dset = file['MISC']['PV1']
dset['PV'].keys()
# Out:
# <KeysViewHDF5 ['INVERTER']>

# %%
df = pd.read_hdf(data_path+'/Schlemminger2022/2018_data_15min.hdf5', key='MISC/ES1/TRANSFORMER')
df.columns
# Out:
# Index(['S_1', 'S_2', 'S_3', 'S_TOT', 'I_1', 'I_2', 'I_3', 'PF_1', 'PF_2',
#        'PF_3', 'PF_TOT', 'P_1', 'P_2', 'P_3', 'P_TOT', 'Q_1', 'Q_2', 'Q_3',
#        'Q_TOT', 'U_1', 'U_2', 'U_3'],
#       dtype='object')

# %%
df[['S_1', 'S_2', 'S_3']].plot()
# Out:
# <AxesSubplot: >
