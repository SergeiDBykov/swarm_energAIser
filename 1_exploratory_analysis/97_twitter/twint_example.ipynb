# %%
import twint 
import pandas as pd
import nest_asyncio
nest_asyncio.apply()
#__import__('IPython').embed()

# %% [markdown]
# pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint

# %%
# Configure
c = twint.Config()
c.Near = "London"
c.Limit = 100
c.Store_csv = True
c.Output = "test.csv"
#c.Geo = "51.5074,0.1278,10km"

c.Since = "2015-12-21"
c.Until = "2015-12-22"
c.Verified = True
c.Count = True
c.Stats = False


# Run
twint.run.Search(c)
# Out:
# 679088513187504129 2015-12-22 00:58:13 +0100 <JohnAmaechi> @misterspike I only play the fighter battles!
# 679088347051106304 2015-12-22 00:57:33 +0100 <JohnAmaechi> @gregmepstein @DanLeBatardShow @HarvardHumanist you'll enjoy the Asimov quote I use, but not humanism per se!
# 679088324531920896 2015-12-22 00:57:28 +0100 <adrianhon> Best of Enemies: solid, solid documentary on 1968 debates between left and right (Vidal &amp; Buckley). Arguably origin of poor TV news today.
# 679088219254882305 2015-12-22 00:57:02 +0100 <JoWoodOfficial> @Locutas74 hey happy Christmas to you !
# 679087120833765376 2015-12-22 00:52:41 +0100 <peterjukes> Sneak Preview of Episode One of the Daniel Morgan Murder Serial - The Call   https://t.co/iLqGRE7w6E   https://t.co/RjbnHhHVjy via @YouTube
# 679087109295222784 2015-12-22 00:52:38 +0100 <Mickey_Helliet> @dougiebrimson @skyf1 @BBC if tiddlywinks was an Olympic sport people would watch it but outside that no interest &amp; defo not TV worthy
# ...

# %%
Tweets_df = pd.read_csv('test.csv', index_col=0)
Tweets_df
# Out:
#                     679088955728535552.1  2015-12-22 00:59:58 CET  2015-12-22  \
# 679088955728535552
# 679088954319183872    679036716771123200  2015-12-22 00:59:58 CET  2015-12-22
# 679088949059547136    679088949059547136  2015-12-22 00:59:56 CET  2015-12-22
# 679088908529967110    679088908529967110  2015-12-22 00:59:47 CET  2015-12-22
# 679088907485642752    679088907485642752  2015-12-22 00:59:47 CET  2015-12-22
# 679088896060366848    679088896060366848  2015-12-22 00:59:44 CET  2015-12-22
# ...                                  ...                      ...         ...
# 679079440891125761    679076213843992578  2015-12-22 00:22:10 CET  2015-12-22
# 679079291066404864    679079291066404864  2015-12-22 00:21:34 CET  2015-12-22
# 679079125995429888    679079125995429888  2015-12-22 00:20:54 CET  2015-12-22
# 679078789121482752    679078789121482752  2015-12-22 00:19:34 CET  2015-12-22
# 679078022788587521    679073158876504064  2015-12-22 00:16:31 CET  2015-12-22
#
# ...
